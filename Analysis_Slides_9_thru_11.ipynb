# %% [markdown]
# # US Computer and Mathematical Employment Analysis
# ----
#
# ### Analysis
# * At nation level in 2017, office and administrative support, sales, and food preparation and serving are the 3 largest major occupations. Computer and mathematical occupations rank No. 14 among 22 major occupation categories.
#   Inside computer and mathematical occupations, software developers, computer user support specialists and computer system analysts occupations had the highest number of employees.
# * At state level in 2017, California, Texas, and New York are the top 3 states had the most people working in computer and mathematical related occupations.
# ---

# %%
#import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#dependencies for plotly
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True) #use plotly for offline plot and inside notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#file source
excel_path = "Resources/state_M2017_dl.xlsx"

#read the excel file
state17_df = pd.read_excel(excel_path, index_col=None)
state17_df.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#    TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ...   H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1922570      0.4      1000     1  ...      15.77   25.01   37.83   17770
# 1    69950        1    36.385  0.71  ...      46.63   64.12    90.8   52130
# 2     1120        6     0.585   0.4  ...      94.45       #       #   84520
# 3    27150      1.6    14.123  0.91  ...      49.19   71.09       #   54040
# 4     1100       12     0.572  1.59  ...          *       *       *   16310
#
#   A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 0   21740    32800   52020   78690    NaN    NaN
# 1   70130    96980  133360  188860    NaN    NaN
# 2  125290   196460       #       #    NaN    NaN
# 3   72610   102320  147860       #    NaN    NaN
# 4   17280    18910   24630   47510   True    NaN
#
# [5 rows x 25 columns]

# %%
state17_df.keys()
# Out:
# Index(['AREA', 'ST', 'STATE', 'OCC_CODE', 'OCC_TITLE', 'OCC_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_Q', 'H_MEAN', 'A_MEAN', 'MEAN_PRSE',
#        'H_PCT10', 'H_PCT25', 'H_MEDIAN', 'H_PCT75', 'H_PCT90', 'A_PCT10',
#        'A_PCT25', 'A_MEDIAN', 'A_PCT75', 'A_PCT90', 'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
#delete some columns
state17_df = state17_df[['ST', 'STATE', 'OCC_CODE', 'OCC_TITLE', 'OCC_GROUP', 
                           'TOT_EMP', 'JOBS_1000', 'A_MEAN', 'MEAN_PRSE','A_MEDIAN']]
state17_df.head()
# Out:
#    ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  TOT_EMP  \
# 0  AL  Alabama  00-0000                  All Occupations     total  1922570
# 1  AL  Alabama  11-0000           Management Occupations     major    69950
# 2  AL  Alabama  11-1011                 Chief Executives  detailed     1120
# 3  AL  Alabama  11-1021  General and Operations Managers  detailed    27150
# 4  AL  Alabama  11-1031                      Legislators  detailed     1100
#
#   JOBS_1000  A_MEAN MEAN_PRSE A_MEDIAN
# 0      1000   43170       0.5    32800
# 1    36.385  111150       0.6    96980
# 2     0.585  207090       3.2   196460
# 3    14.123  120730       0.8   102320
# 4     0.572   25410       4.6    18910

# %%
#delete the rows that the employment estimate is not available (**), replace with na and drop na
state17_df = state17_df.replace("**", np.nan)
state17_df = state17_df.dropna(how="any")

state17_df.count()
# Out:
# ST           35506
# STATE        35506
# OCC_CODE     35506
# OCC_TITLE    35506
# OCC_GROUP    35506
# TOT_EMP      35506
# JOBS_1000    35506
# A_MEAN       35506
# MEAN_PRSE    35506
# A_MEDIAN     35506
# dtype: int64

# %%
state17_df.dtypes
# Out:
# ST            object
# STATE         object
# OCC_CODE      object
# OCC_TITLE     object
# OCC_GROUP     object
# TOT_EMP      float64
# JOBS_1000    float64
# A_MEAN        object
# MEAN_PRSE     object
# A_MEDIAN      object
# dtype: object

# %%
#creat variables to hold the parameters for filter occupations needed
map_occ_code = "15-0000"
map_occ_tit = "Computer and Mathematical Occupations"

#filter the defined occupation catergory
occ_map_df = state17_df.loc[state17_df['OCC_CODE'] == map_occ_code, :]
occ_map_df.head()
# Out:
#       ST       STATE OCC_CODE                              OCC_TITLE  \
# 63    AL     Alabama  15-0000  Computer and Mathematical Occupations
# 784   AK      Alaska  15-0000  Computer and Mathematical Occupations
# 1344  AZ     Arizona  15-0000  Computer and Mathematical Occupations
# 2100  AR    Arkansas  15-0000  Computer and Mathematical Occupations
# 2802  CA  California  15-0000  Computer and Mathematical Occupations
#
#      OCC_GROUP   TOT_EMP  JOBS_1000  A_MEAN MEAN_PRSE A_MEDIAN
# 63       major   39760.0     20.680   81870         1    77590
# 784      major    5450.0     17.124   81820       2.3    76800
# 1344     major   93490.0     34.573   82940       1.2    79550
# 2100     major   23850.0     19.873   68360       2.5    64850
# 2802     major  590550.0     35.373  105380       0.9   100480

# %%
occ_map_df.to_csv("images/occ_map_df.csv", index=False, encoding="utf-8", header=True)

# %%
scl = [
    [0.0, 'rgb(242,240,247)'],
    [0.2, 'rgb(218,218,235)'],
    [0.4, 'rgb(188,189,220)'],
    [0.6, 'rgb(158,154,200)'],
    [0.8, 'rgb(117,107,177)'],
    [1.0, 'rgb(84,39,143)']
]

# %%
#create text to show infor for each state on the map
occ_map_df['text'] = occ_map_df['STATE'] + '<br>' + \
'Annual Median Wage: '+ '<br>' + \
'$' + occ_map_df['A_MEDIAN'].astype(str)
occ_map_df.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       ST       STATE OCC_CODE                              OCC_TITLE  \
# 63    AL     Alabama  15-0000  Computer and Mathematical Occupations
# 784   AK      Alaska  15-0000  Computer and Mathematical Occupations
# 1344  AZ     Arizona  15-0000  Computer and Mathematical Occupations
# 2100  AR    Arkansas  15-0000  Computer and Mathematical Occupations
# 2802  CA  California  15-0000  Computer and Mathematical Occupations
#
#      OCC_GROUP   TOT_EMP  JOBS_1000  A_MEAN MEAN_PRSE A_MEDIAN  \
# 63       major   39760.0     20.680   81870         1    77590
# 784      major    5450.0     17.124   81820       2.3    76800
# 1344     major   93490.0     34.573   82940       1.2    79550
# 2100     major   23850.0     19.873   68360       2.5    64850
# 2802     major  590550.0     35.373  105380       0.9   100480
#
#                                                text
# 63        Alabama<br>Annual Median Wage: <br>$77590
# 784        Alaska<br>Annual Median Wage: <br>$76800
# 1344      Arizona<br>Annual Median Wage: <br>$79550
# 2100     Arkansas<br>Annual Median Wage: <br>$64850
# 2802  California<br>Annual Median Wage: <br>$100480

# %%
#use plotly to generate heapmap for the number of employment
    
data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = occ_map_df['ST'],
    z = occ_map_df['TOT_EMP'].astype(float),
    locationmode = 'USA-states',
    text = occ_map_df['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Number of Employment")
)]

layout = go.Layout(
    title = go.layout.Title(
        text = f'2017 US Employment of {map_occ_tit}'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)

fig = go.Figure(data = data, layout = layout)
plotly.offline.iplot(fig, filename = 'Occupation_map')
# Out:
# <div id="5a55c352-efea-4246-89e9-d1d5cc506518" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("5a55c352-efea-4246-89e9-d1d5cc506518")) {
#     Plotly.newPlot("5a55c352-efea-4246-89e9-d1d5cc506518", [{"autocolorscale": false, "colorbar": {"title": {"text": "Number of Employment"}}, "colorscale": [[0.0, "rgb(242,240,247)"], [0.2, "rgb(218,218,235)"], [0.4, "rgb(188,189,220)"], [0.6, "rgb(158,154,200)"], [0.8, "rgb(117,107,177)"], [1.0, "rgb(84,39,143)"]], "locationmode": "USA-states", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "DC", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "GU", "PR", "VI"], "marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "text": ["Alabama<br>Annual Median Wage: <br>$77590", "Alaska<br>Annual Median Wage: <br>$76800", "Arizona<br>Annual Median Wage: <br>$79550", "Arkansas<br>Annual Median Wage: <br>$64850", "California<br>Annual Median Wage: <br>$100480", "Colorado<br>Annual Median Wage: <br>$92520", "Connecticut<br>Annual Median Wage: <br>$88330", "Delaware<br>Annual Median Wage: <br>$90040", "District of Columbia<br>Annual Median Wage: <br>$106240", "Florida<br>Annual Median Wage: <br>$71670", "Georgia<br>Annual Median Wage: <br>$81930", "Hawaii<br>Annual Median Wage: <br>$77450", "Idaho<br>Annual Median Wage: <br>$66290", "Illinois<br>Annual Median Wage: <br>$83470", "Indiana<br>Annual Median Wage: <br>$69080", "Iowa<br>Annual Median Wage: <br>$74000", "Kansas<br>Annual Median Wage: <br>$69460", "Kentucky<br>Annual Median Wage: <br>$65270", "Louisiana<br>Annual Median Wage: <br>$58510", "Maine<br>Annual Median Wage: <br>$69910", "Maryland<br>Annual Median Wage: <br>$95840", "Massachusetts<br>Annual Median Wage: <br>$92400", "Michigan<br>Annual Median Wage: <br>$75670", "Minnesota<br>Annual Median Wage: <br>$82620", "Mississippi<br>Annual Median Wage: <br>$61900", "Missouri<br>Annual Median Wage: <br>$76030", "Montana<br>Annual Median Wage: <br>$59070", "Nebraska<br>Annual Median Wage: <br>$73820", "Nevada<br>Annual Median Wage: <br>$72260", "New Hampshire<br>Annual Median Wage: <br>$82050", "New Jersey<br>Annual Median Wage: <br>$94830", "New Mexico<br>Annual Median Wage: <br>$72670", "New York<br>Annual Median Wage: <br>$87930", "North Carolina<br>Annual Median Wage: <br>$84120", "North Dakota<br>Annual Median Wage: <br>$62770", "Ohio<br>Annual Median Wage: <br>$76730", "Oklahoma<br>Annual Median Wage: <br>$64980", "Oregon<br>Annual Median Wage: <br>$82940", "Pennsylvania<br>Annual Median Wage: <br>$78580", "Rhode Island<br>Annual Median Wage: <br>$83280", "South Carolina<br>Annual Median Wage: <br>$68200", "South Dakota<br>Annual Median Wage: <br>$60090", "Tennessee<br>Annual Median Wage: <br>$70140", "Texas<br>Annual Median Wage: <br>$85020", "Utah<br>Annual Median Wage: <br>$75810", "Vermont<br>Annual Median Wage: <br>$69250", "Virginia<br>Annual Median Wage: <br>$97390", "Washington<br>Annual Median Wage: <br>$104360", "West Virginia<br>Annual Median Wage: <br>$63210", "Wisconsin<br>Annual Median Wage: <br>$71680", "Wyoming<br>Annual Median Wage: <br>$60380", "Guam<br>Annual Median Wage: <br>$45890", "Puerto Rico<br>Annual Median Wage: <br>$39000", "Virgin Islands<br>Annual Median Wage: <br>$49650"], "z": [39760.0, 5450.0, 93490.0, 23850.0, 590550.0, 109450.0, 49630.0, 17560.0, 42910.0, 198940.0, 140520.0, 9960.0, 14110.0, 172680.0, 57410.0, 35150.0, 35900.0, 31120.0, 20000.0, 11370.0, 124630.0, 142010.0, 111400.0, 94290.0, 11810.0, 84520.0, 8150.0, 30240.0, 19410.0, 19140.0, 139640.0, 14750.0, 259090.0, 129080.0, 7420.0, 148050.0, 31440.0, 53060.0, 158660.0, 14490.0, 39530.0, 8040.0, 54730.0, 353460.0, 48640.0, 7280.0, 201680.0, 157400.0, 10880.0, 76080.0, 2660.0, 580.0, 10660.0, 350.0], "type": "choropleth", "uid": "2b84a90d-7241-4c13-80a7-a4d80c80a7c0"}], {"geo": {"lakecolor": "rgb(255, 255, 255)", "projection": {"type": "albers usa"}, "scope": "usa", "showlakes": true}, "title": {"text": "2017 US ...
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("5a55c352-efea-4246-89e9-d1d5cc506518")) {window._Plotly.Plots.resize(document.getElementById("5a55c352-efea-4246-89e9-d1d5cc506518"));};})</script>

# %%
#use plotly to generate heapmap for the annual median wage of the occupation
data_wage = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = occ_map_df['ST'],
    z = occ_map_df['A_MEDIAN'].astype(float),
    locationmode = 'USA-states',
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Annual Median Wage ($)")
)]

layout_wage = go.Layout(
    title = go.layout.Title(
        text = f'2017 US Employment of {map_occ_tit}'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)

fig_wage = go.Figure(data = data_wage, layout = layout_wage)
plotly.offline.iplot(fig_wage, filename = 'Occupation_map_wage')
# Out:
# <div id="58dfe687-9ada-436b-8db2-052e8ff3e74f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("58dfe687-9ada-436b-8db2-052e8ff3e74f")) {
#     Plotly.newPlot("58dfe687-9ada-436b-8db2-052e8ff3e74f", [{"autocolorscale": false, "colorbar": {"title": {"text": "Annual Median Wage ($)"}}, "colorscale": [[0.0, "rgb(242,240,247)"], [0.2, "rgb(218,218,235)"], [0.4, "rgb(188,189,220)"], [0.6, "rgb(158,154,200)"], [0.8, "rgb(117,107,177)"], [1.0, "rgb(84,39,143)"]], "locationmode": "USA-states", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "DC", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "GU", "PR", "VI"], "marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "z": [77590.0, 76800.0, 79550.0, 64850.0, 100480.0, 92520.0, 88330.0, 90040.0, 106240.0, 71670.0, 81930.0, 77450.0, 66290.0, 83470.0, 69080.0, 74000.0, 69460.0, 65270.0, 58510.0, 69910.0, 95840.0, 92400.0, 75670.0, 82620.0, 61900.0, 76030.0, 59070.0, 73820.0, 72260.0, 82050.0, 94830.0, 72670.0, 87930.0, 84120.0, 62770.0, 76730.0, 64980.0, 82940.0, 78580.0, 83280.0, 68200.0, 60090.0, 70140.0, 85020.0, 75810.0, 69250.0, 97390.0, 104360.0, 63210.0, 71680.0, 60380.0, 45890.0, 39000.0, 49650.0], "type": "choropleth", "uid": "dc8e30eb-dba8-4fbf-b92e-036d148d29a0"}], {"geo": {"lakecolor": "rgb(255, 255, 255)", "projection": {"type": "albers usa"}, "scope": "usa", "showlakes": true}, "title": {"text": "2017 US Employment of Computer and Mathematical Occupations"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("58dfe687-9ada-436b-8db2-052e8ff3e74f")) {window._Plotly.Plots.resize(document.getElementById("58dfe687-9ada-436b-8db2-052e8ff3e74f"));};})</script>

# %%
#pie chart for the number of employment by major occupation

#group by occ_code and calculate the nation data (use the agg function)
aggreations = {'TOT_EMP':"sum"}
major_df = state17_df[state17_df['OCC_GROUP'] == "major"].groupby(
           ['OCC_CODE','OCC_TITLE'],as_index=False).agg(aggreations) #(index=False to make CODE and TITLE columnes not index column, for pie label purpose)            
major_df
# Out:
#    OCC_CODE                                          OCC_TITLE     TOT_EMP
# 0   11-0000                             Management Occupations   7327160.0
# 1   13-0000      Business and Financial Operations Occupations   7518560.0
# 2   15-0000              Computer and Mathematical Occupations   4273060.0
# 3   17-0000           Architecture and Engineering Occupations   2531630.0
# 4   19-0000     Life, Physical, and Social Science Occupations   1154620.0
# 5   21-0000           Community and Social Service Occupations   2113720.0
# 6   23-0000                                  Legal Occupations   1101380.0
# 7   25-0000       Education, Training, and Library Occupations   8800500.0
# 8   27-0000  Arts, Design, Entertainment, Sports, and Media...   1933340.0
# 9   29-0000  Healthcare Practitioners and Technical Occupat...   8562280.0
# 10  31-0000                     Healthcare Support Occupations   4124530.0
# 11  33-0000                     Protective Service Occupations   3467870.0
# 12  35-0000   Food Preparation and Serving Related Occupations  13275170.0
# 13  37-0000  Building and Grounds Cleaning and Maintenance ...   4470290.0
# 14  39-0000              Personal Care and Service Occupations   5177990.0
# 15  41-0000                      Sales and Related Occupations  14638710.0
# 16  43-0000      Office and Administrative Support Occupations  22144580.0
# 17  45-0000         Farming, Fishing, and Forestry Occupations    472900.0
# 18  47-0000            Construction and Extraction Occupations   5762060.0
# 19  49-0000  Installation, Maintenance, and Repair Occupations   5562360.0
# 20  51-0000                             Production Occupations   9083980.0
# 21  53-0000     Transportation and Material Moving Occupations  10027440.0

# %%
#group by occ_code and calculate the nation data (use the agg function)
aggreations = {'TOT_EMP':"sum"}
major_df = state17_df[state17_df['OCC_GROUP'] == "major"].groupby(['OCC_TITLE']).agg(aggreations)

#sort the data based on employment number
major_sort = major_df.sort_values('TOT_EMP', ascending=False)

#make horizon bar
major_bar = major_sort.plot(kind="barh",figsize=(8, 10), 
                            color="#86bf91", zorder=2, width=0.85, legend=False)
plt.gca().invert_yaxis()

# Despine (box invisible)
major_bar.spines['right'].set_visible(False)
major_bar.spines['top'].set_visible(False)
major_bar.spines['bottom'].set_visible(False)


# Switch off ticks
major_bar.tick_params(axis="both", which="both", bottom="off", top="off", 
                      labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = major_bar.get_xticks()
for tick in vals:
      major_bar.axvline(x=tick, linestyle='dashed', alpha=0.5, color='#eeeeee', zorder=1)
        
#set individual bar lables
rank = 0
for i, v in enumerate(major_sort['TOT_EMP']):
    rank = rank + 1
    major_bar.text(v + 3, i + 0.15, str(f"#{rank}: {v}"), color='white', fontweight='bold')
        
        
# Set x-axis label
major_bar.set_xlabel("Employment", labelpad=20, size=12, fontweight='bold')    
# Set y-axis label
major_bar.set_ylabel("Major Occupations", labelpad=20, size=12, fontweight='bold')
# Set title
major_bar.set_title("2017 US Total Employed Persons by Occupations", 
                    size=12, loc="left", fontweight='bold')
#Set background
plt.style.use('dark_background')


#save the figure
plt.savefig("images/major_bar_2017.png",bbox_inches = 'tight')
plt.show()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
#
#
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.

# %%
#group by occ_code and calculate the nation data (use the agg function)
aggreations = {'TOT_EMP':"sum"}
computer_df = state17_df[(state17_df['OCC_CODE'].str.contains("15-1")) | 
                         (state17_df['OCC_CODE'].str.contains("15-2"))].groupby(['OCC_TITLE']).agg(aggreations) 

#sort the data based on employment number
computer_sort = computer_df.sort_values('TOT_EMP', ascending=True)

#make horizon bar
computer_bar = computer_sort.plot(kind="barh",figsize=(8, 10), 
                                  color="#86bf91", zorder=2, width=0.85,legend=False)

# Despine
computer_bar.spines['right'].set_visible(False)
computer_bar.spines['top'].set_visible(False)
computer_bar.spines['bottom'].set_visible(False)

# Switch off ticks
computer_bar.tick_params(axis="both", which="both", bottom="off", top="off", 
                         labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = computer_bar.get_xticks()
for tick in vals:
    computer_bar.axvline(x=tick, linestyle='dashed', alpha=0.5, color='#eeeeee', zorder=1)

# Set x-axis label
computer_bar.set_xlabel("Employment", labelpad=20, size=12, fontweight='bold')
# Set y-axis label
computer_bar.set_ylabel("Detailed Occupations", labelpad=20, size=12, fontweight='bold')
# Set title
computer_bar.set_title("2017 US Employed Persons by Computer and Mathematical Occupations", 
                       size=12, loc="left", fontweight='bold')

plt.style.use('dark_background')

#save the figure
plt.savefig("images/computer_bar_2017.png",bbox_inches = 'tight')
plt.show()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
#
#
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
